# %%
import sys
import os
import json
import pandas as pd
from io import StringIO 
from sklearn.model_selection import train_test_split
from modules.parser import parse_json

# %%
def test(**kwargs):
    print(f"kwargs: {kwargs}")


dirname = os.getcwd()
test(**parse_json({"schemap": "3/schema.json"},"schema",dirname))
# Out:
# kwargs: {'fnlwgt': 'numeric', 'education-num': 'numeric', 'capital-gain': 'numeric', 'capital-loss': 'numeric', 'hours-per-week': 'numeric', 'age': 'catelogue', 'workclass': 'catelogue', 'education': 'catelogue', 'marital-status': 'catelogue', 'occupation': 'catelogue', 'relationship': 'catelogue', 'race': 'catelogue', 'sex': 'catelogue', 'native-country': 'catelogue', 'income': 'catelogue'}

# %%
json.loads('{"hidden_layer_sizes": 200}')
# Out:
# {'hidden_layer_sizes': 200}

# %%
df=pd.read_csv("BCP.csv",index_col=0)
train_X,test_X,train_Y,test_Y=train_test_split(df.drop("Class",axis=1),df["Class"],test_size=0.3)

# %%
pd.concat([train_X,train_Y],axis=1)
# Out:
#                     Clump Thickness  Uniformity of Cell Size  \
# Sample code number
# 1265899                           4                        1
# 1280258                           4                        1
# 1275807                           4                        2
# 1000025                           5                        1
# 830690                            5                        2
# ...                             ...                      ...
# 1072179                          10                        7
# 557583                            5                       10
# 625201                            8                        2
# 1180523                           3                        1
# 1100524                           6                       10
#
#                     Uniformity of Cell Shape  Marginal Adhesion  \
# Sample code number
# 1265899                                    1                  1
# ...

# %%
train_Y
# Out:
# Sample code number
# 1265899    2
# 1280258    2
# 1275807    2
# 1000025    2
# 830690     2
#           ..
# 1072179    4
# 557583     4
# 625201     2
# 1180523    2
# 1100524    4
# Name: Class, Length: 478, dtype: int64

# %%
train_X
# Out:
#                     Clump Thickness  Uniformity of Cell Size  \
# Sample code number
# 1265899                           4                        1
# 1280258                           4                        1
# 1275807                           4                        2
# 1000025                           5                        1
# 830690                            5                        2
# ...                             ...                      ...
# 1072179                          10                        7
# 557583                            5                       10
# 625201                            8                        2
# 1180523                           3                        1
# 1100524                           6                       10
#
#                     Uniformity of Cell Shape  Marginal Adhesion  \
# Sample code number
# 1265899                                    1                  1
# ...

# %%
df=pd.read_csv("BCP_train.csv",index_col=0)
model, result=tp.oneshot(get_model_class("SVM"),df.drop(columns="Class"),df["Class"],eval.accuracy)
print(result["accuracy"])
if not os.path.exists("/1"):
    os.makedirs("/1")
pd.to_pickle(model,"/1/model.pickle")
with open('/1/metadata.json', 'w', encoding='utf-8') as f:
    json.dump(result, f, ensure_ascii=False, indent=4)
# Out:
# 0.9728033472803347
